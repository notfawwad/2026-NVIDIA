# %% [markdown]
# <div style="font-family: 'Segoe UI', Helvetica, Arial, sans-serif; max-width: 950px; margin: 0 auto; padding: 30px; border: 2px solid #76b900; border-radius: 15px; background-color: #ffffff; box-shadow: 0 8px 16px rgba(0,0,0,0.1);">
# <div style="text-align: center; border-bottom: 3px solid #76b900; padding-bottom: 20px; margin-bottom: 30px;">
# <h1 style="color: #333; margin: 0; font-size: 32px; letter-spacing: 1px; text-transform: uppercase;">🚀 Product Requirements Document</h1>
# <p style="color: #76b900; margin: 10px 0 0 0; font-size: 18px; font-weight: bold;">Project: LABS-Opt-FB &nbsp;|&nbsp; Team: Zero. One. Both.</p>
# <p style="color: #666; margin: 5px 0 0 0; font-size: 14px;"><a href="https://github.com/notfawwad/2026-NVIDIA" style="color: #76b900; text-decoration: none;">🔗 GitHub Repository Link (https://github.com/notfawwad/2026-NVIDIA)</a></p>
# </div>
# <h3 style="background-color: #76b900; color: white; padding: 12px 20px; border-radius: 8px; font-size: 20px; margin-top: 0;">👥 1. Team Roles & Responsibilities</h3>
# <table style="width: 100%; border-collapse: collapse; margin-bottom: 30px; font-size: 15px;">
# <tr style="background-color: #f0fdf4; border-bottom: 2px solid #76b900;">
# <th style="text-align: left; padding: 12px; color: #1a5c20;">Role</th>
# <th style="text-align: left; padding: 12px; color: #1a5c20;">Name</th>
# <th style="text-align: left; padding: 12px; color: #1a5c20;">GitHub / Discord</th>
# </tr>
# <tr>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;"><b>Project Lead (Architect), Quality Assurance</b></td>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;">Muhammad Fawad</td>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;">@notfawwad</td>
# </tr>
# <tr>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;"><b>GPU Acceleration PIC, Technical Marketing PIC </b></td>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;">Mohammad Bilal</td>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;">@MHTBeelal</td>
# </tr>
#
# </table>
# <h3 style="background-color: #76b900; color: white; padding: 12px 20px; border-radius: 8px; font-size: 20px;">🏗️ 2. The Architecture</h3>
# <div style="padding: 0 15px 20px 15px;">
# <h4 style="color: #2c3e50; border-left: 4px solid #76b900; padding-left: 10px; margin-bottom: 10px;">🧬 Choice of Quantum Algorithm</h4>
# <ul style="list-style-type: none; padding: 0;">
# <li style="margin-bottom: 10px;"><b>Algorithm:</b> Warm-Started Digitized Counterdiabatic Quantum Optimization (WS-DCQO).</li>
# <li style="margin-bottom: 10px;"><b>Motivation:</b> The LABS problem has a rugged energy landscape. Standard DCQO ramps can get stuck. We use a classical pre-solve to "Warm-Start" the initialization, allowing the CD drive to "tunnel" to the global minimum.</li>
# </ul>
# <h4 style="color: #2c3e50; border-left: 4px solid #76b900; padding-left: 10px; margin-bottom: 10px;">📚 Literature Review</h4>
# <ul style="list-style-type: none; padding: 0;">
# <li><b>Reference:</b> <i>Counterdiabatic Optimized Quantum Control</i>, Hegade et al. (2021).</li>
# <li><b>Relevance:</b> This paper provides the non-adiabatic protocols we adapted for the specific H2 and H4 terms in the LABS Hamiltonian.</li>
# </ul>
# </div>
#
# <h3 style="background-color: #76b900; color: white; padding: 12px 20px; border-radius: 8px; font-size: 20px;">⚡ 3. The Acceleration Strategy</h3>
# <div style="padding: 0 15px 20px 15px;">
# <div style="background-color: #f4fdf4; padding: 15px; border-radius: 8px; border: 1px solid #bbf7d0; margin-bottom: 15px;">
# <strong style="color: #15803d;">🟢 Quantum Acceleration (CUDA-Q)</strong>
# <p style="margin: 5px 0 0 0; color: #444;">Targeting the <code>nvidia-mgpu</code> backend. For N >= 30, we distribute state-vector simulation across multiple GPUs to handle memory overhead.</p>
# </div>
# <div style="background-color: #f4fdf4; padding: 15px; border-radius: 8px; border: 1px solid #bbf7d0; margin-bottom: 15px;">
# <strong style="color: #15803d;">🟢 Classical Acceleration (MTS)</strong>
# <p style="margin: 5px 0 0 0; color: #444;">Offloading the O(N^2) autocorrelation bottleneck. We use <b>CuPy</b> to evaluate batches of 1,000+ neighbor flips simultaneously on GPU tensor cores.</p>
# </div>
# <p style="margin-bottom: 0;"><b>Hardware Targets:</b> Dev on <b>qBraid CPU</b> &rarr; Debug on <b>Brev L4</b> &rarr; Prod on <b>Brev A100-80GB</b>.</p>
# </div>
# <h3 style="background-color: #76b900; color: white; padding: 12px 20px; border-radius: 8px; font-size: 20px;">🧪 4. The Verification Plan</h3>
# <table style="width: 100%; border-collapse: collapse; margin-bottom: 30px; font-size: 15px;">
# <tr style="background-color: #f0fdf4; border-bottom: 2px solid #76b900;">
# <th style="text-align: left; padding: 12px; color: #1a5c20;">Check Type</th>
# <th style="text-align: left; padding: 12px; color: #1a5c20;">Success Criteria</th>
# </tr>
# <tr>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;"><b>Unit Testing Strategy</b></td>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;"><code>unittest</code> framework with AI guardrails. Generated interactions must match theoretical combinatorial counts.</td>
# </tr>
# <tr>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;"><b>Symmetry Check</b></td>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;">Assert E(S) == E(-S) (Inversion) and E(S) == E(S_rev) (Reversal).</td>
# </tr>
# <tr>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;"><b>Ground Truth</b></td>
# <td style="padding: 12px; border-bottom: 1px solid #e0e0e0;">Barker-13 Sequence must return exactly <b>E=6.0</b>.</td>
# </tr>
# </table>
# <h3 style="background-color: #76b900; color: white; padding: 12px 20px; border-radius: 8px; font-size: 20px;">📊 5. Execution & Success Metrics</h3>
# <div style="display: flex; justify-content: space-between; text-align: center; margin-bottom: 20px; gap: 10px;">
# <div style="flex: 1; background: #fff; border: 2px solid #76b900; border-radius: 10px; padding: 15px;">
# <div style="font-size: 24px; font-weight: bold; color: #333;">&gt; 0.85</div>
# <div style="font-size: 13px; color: #666; font-weight: bold;">Approximation Ratio (N=40)</div>
# </div>
# <div style="flex: 1; background: #fff; border: 2px solid #76b900; border-radius: 10px; padding: 15px;">
# <div style="font-size: 24px; font-weight: bold; color: #333;">5x</div>
# <div style="font-size: 13px; color: #666; font-weight: bold;">CuPy Speedup vs NumPy</div>
# </div>
# <div style="flex: 1; background: #fff; border: 2px solid #76b900; border-radius: 10px; padding: 15px;">
# <div style="font-size: 24px; font-weight: bold; color: #333;">N=50</div>
# <div style="font-size: 13px; color: #666; font-weight: bold;">Max Scale Target</div>
# </div>
# </div>
# <div style="padding: 0 15px;">
# <p><b>Agentic Workflow:</b> Human-in-the-loop validation. QA Lead runs tests.py immediately on AI code generation. Failures loop back to Agent for refactoring.</p>
# <p><b>Visualization Plan:</b> Plot 1: Energy Convergence Heatmap (Quantum Seed vs Random). Plot 2: Scaling Wall-Clock Time (CPU vs GPU).</p>
# </div>
# <h3 style="background-color: #76b900; color: white; padding: 12px 20px; border-radius: 8px; font-size: 20px;">⏱️ 6. Resource Management Plan</h3>
# <div style="padding: 0 15px;">
# <p style="line-height: 1.6; color: #333;">
# <b>Strategy:</b> "Develop-Local, Run-Cloud." All logic verification happens on qBraid CPU.
# <br><b>Cost Control:</b> Strict <b>30-minute shutdown rule</b> for Brev instances. Expensive A100 credits are reserved exclusively for the final 2 hours of benchmarking.
# </p>
# </div>
# <div style="text-align: center; margin-top: 40px; border-top: 1px solid #ddd; padding-top: 20px;">
# <sub style="color: #888; font-size: 12px; letter-spacing: 1px;">GENERATED FOR NVIDIA IQUHACK 2026</sub>
# </div>
# </div>
